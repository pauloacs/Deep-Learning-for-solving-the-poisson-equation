# %% [markdown]
# <a href="https://colab.research.google.com/github/pauloacs/Deep-Learning-for-solving-the-poisson-equation/blob/main/IV_PINN/PINN_phi_sigma_script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp '/content/drive/MyDrive/all_data_vanKarman_reduced_complete.hdf5' all_data.hdf5

# %%
from numba import njit
import tensorflow as tf
import os
import shutil
import time
import h5py
import keras
import numpy as np
import math

def read_dataset(path=None, split=0.9, print_shape=False):

    x = []
    y = []
    hdf5_file = h5py.File(path, "r")
    x = hdf5_file["sim_data"][:117, 21:26, ...]
    y = hdf5_file["sim_data"][:117, 22:27, ...]
    sim_no = hdf5_file["sim_no"][:5, 0]
    hdf5_file.close()

    times = 49

    @njit
    def index(array, item):
      for idx, val in np.ndenumerate(array):
        if val == item:
            return idx
    # If no item was found return None, other return types might be a problem due to
    # numbas type inference.
  
    max_0 = np.max( x[...,0] )
    max_1 = np.max( x[...,1] )
    max_2 = np.max( x[...,2] )

    x_mod = x * (x!=-100)

    min_0 = np.min( x_mod[...,0] )
    min_1 = np.min( x_mod[...,1] )
    min_2 = np.min( x_mod[...,2] )

    max_min_list = [max_0, max_1, max_2 , min_0 , min_1 ,min_2]


    y = y[...,0:3]

    for i in range(y.shape[0]):
      indice = index(y[i,0,:,0] , -100.0 )[0]
      if np.max(y[i,:,:indice,0])-np.min(y[i,:,:indice,0]) != 0:
        y[i,:,:indice,0] = (y[i,:,:indice,0] - np.ones((y[i,:,:indice,0].shape))* min_0 )/(max_0 - min_0)
        y[i,:,:indice,1] = (y[i,:,:indice,1] - np.ones((y[i,:,:indice,1].shape))* min_1 )/(max_1 - min_1)
        y[i,:,:indice,2] = (y[i,:,:indice,2] - np.ones((y[i,:,:indice,2].shape))* min_2 )/(max_2 - min_2)

    for i in range(x.shape[0]):
      indice = index(x[i,0,:,0] , -100.0 )[0]
      if np.max(x[i,:,:indice,0])-np.min(x[i,:,:indice,0]) != 0:
        x[i,:,:indice,0] = (x[i,:,:indice,0] - np.ones((x[i,:,:indice,0].shape))* min_0 )/(max_0 - min_0)
        x[i,:,:indice,1] = (x[i,:,:indice,1] - np.ones((x[i,:,:indice,1].shape))* min_1 )/(max_1 - min_1)
        x[i,:,:indice,2] = (x[i,:,:indice,2] - np.ones((x[i,:,:indice,2].shape))* min_2 )/(max_2 - min_2)


    t = np.zeros(shape=(x.shape[0],x.shape[1],x.shape[2] ,1))

    for i in range(x.shape[1]):
      t[:,i,:,:] = np.ones((x.shape[0],x.shape[2],1)) * (i - math.floor(i/(times+1))*(times+1) ) * 0.1

    x = np.concatenate((x,t), axis=3)



    total_sim = x.shape[0]

    x_train = x[:int(total_sim * split), ...]
    y_train = y[:int(total_sim * split), ...]
    x_test = x[int(total_sim * split):total_sim, ...]
    y_test = y[int(total_sim * split):total_sim, ...]
    sim_no_train = sim_no[:int(total_sim * split), ...]
    sim_no_test = sim_no[int(total_sim * split):total_sim, ...]


    if print_shape:
        print("total_sim: {}\nx_train.shape: {}\ny_train.shape: {}\nx_test.shape: {}\ny_test.shape: {}\n".format(
            total_sim,
            x_train.shape,
            y_train.shape,
            x_test.shape,
            y_test.shape))

    return x_train, y_train, x_test, y_test, max_min_list

hdf5_path = '/content/all_data.hdf5'
x_train, y_train, x_test, y_test, max_min_list = read_dataset(hdf5_path, split=0.9, print_shape=True)


assert not np.any(np.isnan(x_train))
assert not np.any(np.isnan(y_train))

assert not np.any(np.isnan(x_test))
assert not np.any(np.isnan(y_test))


path = '/content/obstacle.hdf5'
hdf5_file = h5py.File(path, "r")

coords = hdf5_file["obstacle"][...]

hdf5_file.close()


def denormalize_data(input):

  ux = input[...,0:1]
  uy = input[...,1:2]
  p = input[...,2:3]

  ux = (max_0 - min_0) * ux  + np.ones((ux .shape))*min_0
  uy = (max_1 - min_1) * uy + np.ones((uy.shape))*min_1
  p = (max_2 - min_2) * p + np.ones((p.shape))*min_2

  x_new = np.concatenate([ux, uy, p], axis = -1)
  
  return x_new
  

max_0 = max_min_list[0]
max_1 = max_min_list[1]
max_2 = max_min_list[2]

min_0 = max_min_list[3]
min_1 = max_min_list[4]
min_2 = max_min_list[5]

@njit
def index(array, item):
    for idx, val in np.ndenumerate(array):
        if val == item:
            return idx

indice = index(np.array(x_test[0,0,:,0]) , -100.0 )[0]

coords_data = x_test[0:1,:,:indice,3:6]

N= indice
T = coords_data.shape[1]

x_cord = coords_data[...,0].flatten().reshape(1,N*T,1)
y_cord = coords_data[...,1].flatten().reshape(1,N*T,1)
t_cord = coords_data[...,2].flatten().reshape(1,N*T,1)

x_data = np.concatenate([x_cord,y_cord,t_cord], axis=-1).reshape(1, 1,N*T, 3)

#introduce the initial condition: - starting from 0

x_data_initial = x_test[0:1,0:1,:indice,3:6]
x_data_initial[0:1,0:1,:,2:3] = np.zeros(shape=(x_data_initial[...,2:3].shape))
x_data = np.concatenate([x_data_initial , x_data], axis=2)

data = tf.data.Dataset.from_tensor_slices(x_data)

 #----------------</ data with initial condition >-------------------

ux = y_test[0,:,:indice,0].flatten().reshape(1,N*T,1)
uy = y_test[0,:,:indice,1].flatten().reshape(1,N*T,1)
p  = y_test[0,:,:indice,2].flatten().reshape(1,N*T,1)

ux = (max_0 - min_0) *ux + np.ones((ux.shape))*min_0
uy = (max_1 - min_1) *uy + np.ones((uy.shape))*min_1
p = (max_2 - min_2) * p + np.ones((p.shape))*min_2

y_data = np.concatenate([ux,uy,p], axis=-1).reshape(1,N*T, 3)

y_true_initial = x_test[0,0:1,:indice,0:3]

ux = y_true_initial[...,0:1]
uy = y_true_initial[...,1:2]
p = y_true_initial[...,2:3]

ux = (max_0 - min_0) * ux  + np.ones((ux .shape))*min_0
uy = (max_1 - min_1) * uy + np.ones((uy.shape))*min_1
p = (max_2 - min_2) * p + np.ones((p.shape))*min_2

y_true_initial = np.concatenate([ux,uy,p], axis=-1)

y_data = np.concatenate([y_true_initial , y_data], axis=1)



# lb = x_data[...,0:3].min()
# ub = x_data[...,0:3].max()

lb = np.min(x_data[0,0:1,:,0:3], axis=1)
ub = np.max(x_data[0,0:1,:,0:3], axis=1)


def normalize_X(X):
  x_norm  = 2.0 *(X[...,0:1]-lb[0][0])/(ub[0][0]-lb[0][0])-1.0 
  y_norm  = 2.0 *(X[...,1:2]-lb[0][1])/(ub[0][1]-lb[0][1])-1.0 
  t_norm  = 2.0 *(X[...,2:3]-lb[0][2])/(ub[0][2]-lb[0][2])-1.0 
  X_normalized = tf.concat([x_norm, y_norm , t_norm], axis = -1)
  return X_normalized


def dense_model():
  input_layer = tf.keras.Input (shape=( None, 3))
  x = tf.keras.layers.Lambda(normalize_X)(input_layer)
  x = tf.keras.layers.Dense(40, activation='tanh')(x)
  x = tf.keras.layers.Dense(40, activation='tanh')(x)
  x = tf.keras.layers.Dense(40, activation='tanh')(x)
  x = tf.keras.layers.Dense(40, activation='tanh')(x)
  x = tf.keras.layers.Dense(40, activation='tanh')(x)
  x = tf.keras.layers.Dense(40, activation='tanh')(x)
  x = tf.keras.layers.Dense(40, activation='tanh')(x)
  x = tf.keras.layers.Dense(40, activation='tanh')(x)
  output_layer = tf.keras.layers.Dense(5)(x)
  
  model = tf.keras.Model(inputs=[input_layer], outputs = [output_layer])

  print(model.summary())
  return model



model_ref = dense_model()

def get_masks(coords):
    x = x_data[0,0:1,indice:,...]

    indice_cords = index(coords[0,:,0] , -100.0 )[0]

    coords = coords[0:1,:indice_cords,:]

    mask_obstacle = np.zeros((x_data[0,0:1,:,1].shape), dtype = bool)

    for i in range(coords.shape[1]):
      mask_obstacle = mask_obstacle | ( np.isclose(x_data[0,:,:,0:2],  coords[:,i,:])[...,0] & np.isclose(x_data[0,:,:,0:2],  coords[:,i,:])[...,1])

    mask_obstacle = mask_obstacle[:,indice:]  #excluding the IC

    y_max = np.max(x[:,:,1])
    y_min = np.min(x[:,:,1])

    mask_wall = np.isclose(x[:,:,1],y_max) | np.isclose(x[:,:,1],y_min)
    n_wall = np.sum(mask_wall)
    
    x_max = np.max(x[:,:,0])
    x_min = np.min(x[:,:,0])

    mask_outlet = np.isclose(x[:,:,0],x_max)

    n_outlet = np.sum(mask_wall)

    mask_inlet = np.isclose(x[:,:,0],x_min)

    n_inlet = np.sum(mask_inlet)

    n_obstacle = np.sum(mask_obstacle)

    return mask_wall, mask_outlet, mask_inlet, mask_obstacle ,n_wall, n_outlet, n_inlet, n_obstacle


mask_wall, mask_outlet, mask_inlet, mask_obstacle ,n_wall, n_outlet, n_inlet, n_obstacle = get_masks(coords)

import random 
idx_f_model = random.sample(range(0, x_data.shape[2]), 50000)


def net_uv(data):

    dtype = "float32"
    x = tf.convert_to_tensor(data[0:1,:,0:1], dtype=dtype)
    y = tf.convert_to_tensor(data[0:1,:,1:2], dtype=dtype)
    t = tf.convert_to_tensor(data[0:1,:,2:3], dtype=dtype)

    with tf.GradientTape(persistent=True) as tape:
      tape.watch(x)
      tape.watch(y)

      psip = model_ref(tf.stack([x, y, t], axis=2))
      psi = psip[...,0:1]
      p = psip[...,1:2]
      ux = tape.gradient(psi, y)
      uy = - tape.gradient(psi, x)

    return ux, uy, p



#loss function NS in all cells

from numpy import random

@tf.function
def f_model_cont(data):
  
  
  dtype = "float32"

  x = tf.convert_to_tensor(data[0:1,:,0:1], dtype=dtype)
  y = tf.convert_to_tensor(data[0:1,:,1:2], dtype=dtype)
  t = tf.convert_to_tensor(data[0:1,:,2:3], dtype=dtype)

  x = tf.experimental.numpy.take(x, idx_f_model, axis=1)
  y = tf.experimental.numpy.take(y, idx_f_model, axis=1)
  t = tf.experimental.numpy.take(t, idx_f_model, axis=1)

  with tf.GradientTape(persistent=True) as tape:
    tape.watch(x)
    tape.watch(y)
    tape.watch(t)

    psi_p_sigma = model_ref(tf.stack([x, y, t], axis=2))
    psi = psi_p_sigma[:,0:1]
    p = psi_p_sigma[:,1:2]
    sigma_11 = psi_p_sigma[:,2:3]
    sigma_22 = psi_p_sigma[:,3:4]
    tau_12 = psi_p_sigma[:,4:5]

    ux = tape.gradient(psi, y)
    uy = - tape.gradient(psi, x)

  ux_x = tape.gradient(ux,x)
  ux_y = tape.gradient(ux,y)

  uy_x = tape.gradient(uy, x)
  uy_y = tape.gradient(uy,y)

  ux_t = tape.gradient(ux,t)
  uy_t = tape.gradient(uy,t)

  p_x = tape.gradient(p,x)
  p_y = tape.gradient(p,y)

  sigma_11_x = tape.gradient(sigma_11,x)
  sigma_22_y = tape.gradient(sigma_22,y)

  tau_12_x = tape.gradient(tau_12,x)
  tau_12_y = tape.gradient(tau_12,y)


  # cont_residual = tf.square(ux_x + uy_y)

  nu= 1.51e-4
  Euler_x = tf.square(ux_t + ux * ux_x + uy * ux_y + p_x - sigma_11_x - tau_12_y)
  Euler_y = tf.square(uy_t + ux * uy_x + uy * uy_y + p_y - tau_12_x - sigma_22_y)
 
  sigma_11_eq = tf.square(-p + 2 *nu * ux_x - sigma_11)
  sigma_22_eq = tf.square(-p + 2 *nu * uy_x - sigma_22)
  tau_12_eq = tf.square(nu * (ux_y + uy_x) - tau_12)

  # cont_residual = tf.reduce_mean(tf.square(cont_residual))
  Euler_x_residual = tf.reduce_mean(tf.square(Euler_x))
  Euler_y_residual = tf.reduce_mean(tf.square(Euler_y))

  sigma_11_eq_residual =  tf.reduce_mean(tf.square(sigma_11_eq))
  sigma_22_eq_residual =  tf.reduce_mean(tf.square(sigma_22_eq))
  tau_12_eq_residual =  tf.reduce_mean(tf.square(tau_12_eq))

  return Euler_x_residual, Euler_y_residual, sigma_11_eq_residual, sigma_22_eq_residual, tau_12_eq_residual


def eq_loss_NS_2():
  def equation_loss(x ,y_true):

      Euler_x_residual, Euler_y_residual, sigma_11_eq_residual, sigma_22_eq_residual, tau_12_eq_residual = f_model_cont(x)

      # dtype = "float32"

      ux, uy, p = net_uv(x)

      ux_IC_pred = ux[:,:indice,:]
      uy_IC_pred = uy[:,:indice,:]
      p_IC_pred =  p[:,:indice,:]

      ux_IC_true = y_true[:,:indice,0:1]
      uy_IC_true = y_true[:,:indice,1:2]
      p_IC_true =  y_true[:,:indice,2:3]

      ux = ux[:,indice:,0]
      uy = uy[:,indice:,0]
      p =  p[:,indice:,0]

      ux_inlet_BC = y_true[:,indice:,0][mask_inlet != 0]
      
      ux_pred_obstacle = ux[mask_obstacle != 0]
      uy_pred_obstacle = uy[mask_obstacle != 0]

      ux_pred_wall = ux[mask_wall != 0]
      uy_pred_wall = uy[mask_wall != 0]

      p_pred_outlet = p * mask_outlet 

      #dp_dx_inlet = p_x[:,indice:,0][mask_inlet != 0] 
      #dp_dy_wall =  p_y[:,indice:,0][mask_wall != 0] 
      #dux_dx_outlet = ux_x[:,indice:,0][mask_outlet != 0] 

      ux_inlet_pred = ux[mask_inlet != 0]
      uy_inlet_pred = uy[mask_inlet != 0]


      ## to check each loss durint training
    
      # loss_p_inlet = tf.reduce_mean(tf.square(dp_dx_inlet))

      loss_u_inlet = tf.reduce_mean(tf.square(ux_inlet_BC - ux_inlet_pred)) + tf.reduce_mean(tf.square(uy_inlet_pred))

      loss_p_outlet = tf.reduce_mean(tf.square(p_pred_outlet))

      # loss_u_outlet = tf.reduce_mean(tf.square(dux_dx_outlet))

      loss_u_wall = tf.reduce_mean(tf.square(ux_pred_wall)) + tf.reduce_mean(tf.square(uy_pred_wall))
                    
      loss_u_obstacle = tf.reduce_mean(tf.square(ux_pred_obstacle)) + tf.reduce_mean(tf.square(uy_pred_obstacle))

      # loss_p_wall = tf.reduce_mean(tf.square(dp_dy_wall))


      ##relevant losses


      loss_equations = Euler_x_residual + Euler_y_residual + sigma_11_eq_residual + sigma_22_eq_residual + tau_12_eq_residual

      loss_dirichlet = loss_u_inlet + loss_u_wall + loss_u_obstacle

      loss_neumann = loss_p_outlet

      loss_IC = tf.reduce_mean(tf.square(ux_IC_true - ux_IC_pred)) + tf.reduce_mean(tf.square(uy_IC_true - uy_IC_pred)) +tf.reduce_mean(tf.square(p_IC_true - p_IC_pred))

      # print('loss_p_inlet:' + str(loss_p_inlet) + '\n loss_u_inlet:' + str(loss_u_inlet) +'\n loss_u_wall:' + str(loss_u_wall) + '\n loss_p_outlet:' + str(loss_p_outlet) + \
      #       '\n loss_u_outlet:' + str(loss_u_outlet) + '\n loss_p_wall:' + str(loss_p_wall) + \
      #       '\n cont_residual:' + str(cont_residual) + '\n NSx_residual:' + str(NSx_residual) +  '\n NSy_residual:' + str(NSy_residual) +  '\n loss_IC:' + str(loss_IC)  )

      print( '\n loss_u_inlet:' + str(loss_u_inlet) +'\n loss_u_wall:' + str(loss_u_wall) + '\n loss_p_outlet:' + str(loss_p_outlet) + \
             '\n Euler_x_residual:' + str(Euler_x_residual) +  '\n Euler_y_residual:' + str(Euler_y_residual) +  '\n loss_IC:' + str(loss_IC)  )


      return     loss_equations + 2* loss_dirichlet + 2*loss_neumann + 2* loss_IC

  return equation_loss

loss_object1 = tf.keras.losses.MeanSquaredError()

def perform_validation():
  losses = []

  for step, (x_batch_test) in enumerate (data):

    x_batch_test = tf.cast(x_batch_test, dtype='float32')

    ux,uy,p = net_uv(x_batch_test)
    val_logits = tf.concat([ux, uy, p] , axis=2)


    #val_loss = loss_object(y_true= y_val , y_pred = val_logits, x=x_val)
    val_loss = loss_object1(y_true= y_data[0:1,:,0:3] , y_pred = val_logits)
    losses.append(val_loss)
    #val_acc_metric(y_val,val_logits)
  return losses

#coding the training
#@tf.function
def apply_gradient(optimizer, model , x):
  with tf.GradientTape() as tape:
    #logits = model_ref(x)  #predictions from the model at this moment
    #loss_value = loss_object(y_true = y , y_pred = logits, x=x) #calculate loss given the predictions - logits
    loss_value = loss_object(x=x, y_true = y_data[0:1,:,0:3])
  gradients = tape.gradient(loss_value, model.trainable_weights)
  optimizer.apply_gradients(zip(gradients,model.trainable_weights)) #zip to build tuple

  return loss_value # logits, loss_value 

#@tf.function
def train_data_for_one_epoch():
  losses = []  #loss per batch
  
  #pbar=tqdm(total=len(list(enumerate(train))), position=0, leave = True, bar_format = '{1_bar}{bar}| {n_fms}/{total_fms} ')

  for step, (x_batch_train) in enumerate (data):

    x_batch_train = tf.cast(x_batch_train, dtype='float32')
    
    loss_value = apply_gradient(optimizer , model_ref , x_batch_train)

    losses.append(loss_value)

    #train_acc_metric(y_batch_train, logits)
    #pbar.set_description("Training los for step %.4f" % (int(step),float(loss_value)))
    #pbar.update()
    #progbar.update(step+1)

  return losses


loss_object = eq_loss_NS_2()
lr = 5e-4
optimizer = tf.keras.optimizers.Adam(learning_rate=lr, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.45*lr, amsgrad=True)


#from tqdm import tqdm 
import math


epochs = 1000
epochs_val_losses, epochs_train_losses = [], []

train_len = 1

for epoch in range(epochs):
  
  #progbar = tf.keras.utils.Progbar(math.ceil(train_len/batch_size))

  print('Start of epoch %d' %(epoch,))

  losses_train = train_data_for_one_epoch()
  #train_acc = train_acc_metric.result()

  losses_val  = perform_validation()
  #val_acc = val_acc_metric.result()

  losses_train_mean = np.mean(losses_train)
  losses_val_mean = np.mean(losses_val)
  #epochs_val_losses.append(losses_val_mean)
  epochs_train_losses .append(losses_train_mean)
  #print('Epoch %s: loss: %.4f \n' % (epoch,float(losses_train_mean)), flush = True)
  print('Epoch %s: loss: %.4f real_loss: %.4f \n' % (epoch,float(losses_train_mean), float(losses_val_mean)), flush = True)
  #train_acc_metric.reset_states()
  #val_acc_metric.reset_states()


# ## save model


model_ref.compile(optimizer,loss_object)
#loss_object = tf.keras.losses.MeanSquaredError()

# score = model_ref.evaluate(x_data[0,...],y_data, verbose=1)

# print('Average Mean Squared Error:', score)
model_ref.save('my_model_ref.h5')


import numpy
import tensorflow as tf
import tensorflow_probability as tfp


def function_factory(model, loss, x, y_true):#, y_prev):
    """A factory to create a function required by tfp.optimizer.lbfgs_minimize.
    Args:
        model [in]: an instance of `tf.keras.Model` or its subclasses.
        loss [in]: a function with signature loss_value = loss(pred_y, true_y).
        train_x [in]: the input part of training data.
        train_y [in]: the output part of training data.
    Returns:
        A function that has a signature of:
            loss_value, gradients = f(model_parameters).
    """

    # obtain the shapes of all trainable parameters in the model
    shapes = tf.shape_n(model.trainable_variables)
    n_tensors = len(shapes)

    # we'll use tf.dynamic_stitch and tf.dynamic_partition later, so we need to
    # prepare required information first
    count = 0
    idx = [] # stitch indices
    part = [] # partition indices

    for i, shape in enumerate(shapes):
        n = numpy.product(shape)
        idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32), shape))
        part.extend([i]*n)
        count += n

    part = tf.constant(part)

    @tf.function
    def assign_new_model_parameters(params_1d):
        """A function updating the model's parameters with a 1D tf.Tensor.
        Args:
            params_1d [in]: a 1D tf.Tensor representing the model's trainable parameters.
        """

        params = tf.dynamic_partition(params_1d, part, n_tensors)
        for i, (shape, param) in enumerate(zip(shapes, params)):
            model.trainable_variables[i].assign(tf.reshape(param, shape))

    # now create a function that will be returned by this factory
    @tf.function
    def f(params_1d):
        """A function that can be used by tfp.optimizer.lbfgs_minimize.
        This function is created by function_factory.
        Args:
           params_1d [in]: a 1D tf.Tensor.
        Returns:
            A scalar loss and the gradients w.r.t. the `params_1d`.
        """

        # use GradientTape so that we can calculate the gradient of loss w.r.t. parameters
        with tf.GradientTape() as tape:
            # update the parameters in the model
            assign_new_model_parameters(params_1d)
            # calculate the loss
            loss_value = loss(x=x, y_true = y_true)#, y_prev = y_prev)
        # calculate gradients and convert to 1D tf.Tensor
        grads = tape.gradient(loss_value, model.trainable_variables)
        grads = tf.dynamic_stitch(idx, grads)

        #grad_flat = []
        #for g in grads:
        #    grad_flat.append(tf.reshape(g, [-1]))
        #grad_flat = tf.concat(grad_flat, 0)

        ux,uy,p = net_uv(x)
        val_logits = tf.concat([ux, uy, p] , axis=2)

        val_loss = loss_object1(y_true= y_data[0:1,:,0:3] , y_pred = val_logits[:,:,:])

        # print out iteration & loss
        f.iter.assign_add(1)
        tf.print("Iter:", f.iter, "loss:", loss_value, "loss_val:", val_loss)

        # store loss value so we can retrieve later
        tf.py_function(f.history.append, inp=[loss_value], Tout=[])

        return loss_value, grads

    # store these information as members so we can use them outside the scope
    f.iter = tf.Variable(0)
    f.idx = idx
    f.part = part
    f.shapes = shapes
    f.assign_new_model_parameters = assign_new_model_parameters
    f.history = []

    return f

def plot_helper(inputs, outputs, title, fname):
    """Plot helper"""
    pyplot.figure()
    pyplot.tricontourf(inputs[:, 0], inputs[:, 1], outputs.flatten(), 100)
    pyplot.xlabel("x")
    pyplot.ylabel("y")
    pyplot.title(title)
    pyplot.colorbar()
    pyplot.savefig(fname)




#model = load_model('my_model.h5')
# use float64 by default
#tf.keras.backend.set_floatx("float32")

for step, (x_batch_train) in enumerate (data):
  x = tf.cast(x_batch_train, dtype='float32')

loss = eq_loss_NS_2()
func = function_factory(model_ref, loss, x, y_data[0:1,:,0:3])#, y_prev)

# convert initial model parameters to a 1D tf.Tensor
init_params = tf.dynamic_stitch(func.idx, model_ref.trainable_variables)

# train the model with L-BFGS solver
results = tfp.optimizer.lbfgs_minimize(value_and_gradients_function=func, initial_position=init_params, max_iterations=5000, tolerance=1e-10)

# after training, the final optimized parameters are still in results.position
# so we have to manually put them back to the model
func.assign_new_model_parameters(results.position)

# print out history
print("\n"+"="*80)
print("History")
print("="*80)
print(*func.history, sep='\n')
# Out:
# total_sim: 1
# x_train.shape: (0, 5, 14000, 6)
# y_train.shape: (0, 5, 14000, 3)
# x_test.shape: (1, 5, 14000, 6)
# y_test.shape: (1, 5, 14000, 3)
#
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, None, 3)]         0
# _________________________________________________________________
# lambda_7 (Lambda)            (None, None, 3)           0
# _________________________________________________________________
# dense_58 (Dense)             (None, None, 40)          160
# _________________________________________________________________
# dense_59 (Dense)             (None, None, 40)          1640
# _________________________________________________________________
# dense_60 (Dense)             (None, None, 40)          1640
# _________________________________________________________________
# dense_61 (Dense)             (None, None, 40)          1640
# _________________________________________________________________
# dense_62 (Dense)             (None, None, 40)          1640
# _________________________________________________________________
# dense_63 (Dense)             (None, None, 40)          1640
# _________________________________________________________________
# dense_64 (Dense)             (None, None, 40)          1640
# _________________________________________________________________
# dense_65 (Dense)             (None, None, 40)          1640
# _________________________________________________________________
# dense_66 (Dense)             (None, None, 5)           205
# =================================================================
# Total params: 11,845
# Trainable params: 11,845
# Non-trainable params: 0
# _________________________________________________________________
# None
# Start of epoch 0
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
#
#  loss_u_inlet:tf.Tensor(0.8672046, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.036388267, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.7029833e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.6105397e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(4.828109e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.8731526, shape=(), dtype=float32)
# Epoch 0: loss: 3.6902 real_loss: 0.1809
#
# Start of epoch 1
#
#  loss_u_inlet:tf.Tensor(0.5383746, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.10439486, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.890431e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.88891e-08, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.0064734e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.5776732, shape=(), dtype=float32)
# Epoch 1: loss: 2.9635 real_loss: 0.1211
#
# Start of epoch 2
#
#  loss_u_inlet:tf.Tensor(0.3315634, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.19362006, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(1.5689493e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.168236e-08, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.08938e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.38923302, shape=(), dtype=float32)
# Epoch 2: loss: 2.9268 real_loss: 0.1007
#
# Start of epoch 3
#
#  loss_u_inlet:tf.Tensor(0.25221735, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.24203366, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(1.2148881e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(9.095043e-08, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.831387e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.31691134, shape=(), dtype=float32)
# Epoch 3: loss: 3.0898 real_loss: 0.1017
#
# Start of epoch 4
#
#  loss_u_inlet:tf.Tensor(0.2502291, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.23364054, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(1.6679807e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.2497712e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.224069e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.31511125, shape=(), dtype=float32)
# Epoch 4: loss: 3.0583 real_loss: 0.1140
#
# Start of epoch 5
#
#  loss_u_inlet:tf.Tensor(0.2905496, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.19489501, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.335586e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(8.860431e-08, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.8005775e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.34869632, shape=(), dtype=float32)
# Epoch 5: loss: 2.9053 real_loss: 0.1343
#
# Start of epoch 6
#
#  loss_u_inlet:tf.Tensor(0.3583214, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.14860345, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.7878166e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.1017085e-08, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.2393141e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.40267673, shape=(), dtype=float32)
# Epoch 6: loss: 2.7756 real_loss: 0.1586
#
# Start of epoch 7
#
#  loss_u_inlet:tf.Tensor(0.4378241, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.108705804, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.8882454e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.9170209e-08, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.8818133e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.4639336, shape=(), dtype=float32)
# Epoch 7: loss: 2.7348 real_loss: 0.1804
#
# Start of epoch 8
#
#  loss_u_inlet:tf.Tensor(0.5081268, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.08146298, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.7488057e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.4532404e-08, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.619749e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.51643246, shape=(), dtype=float32)
# Epoch 8: loss: 2.7622 real_loss: 0.1938
#
# Start of epoch 9
#
#  loss_u_inlet:tf.Tensor(0.5500897, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.0671016, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.5951245e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.35144615e-08, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.3720053e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.5460128, shape=(), dtype=float32)
# Epoch 9: loss: 2.7953 real_loss: 0.1961
#
# Start of epoch 10
#
#  loss_u_inlet:tf.Tensor(0.55565804, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06304258, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.5831845e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.5269423e-08, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.1557697e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.54719704, shape=(), dtype=float32)
# Epoch 10: loss: 2.7885 real_loss: 0.1886
#
# Start of epoch 11
#
#  loss_u_inlet:tf.Tensor(0.52936196, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06684305, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.7049473e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.2351822e-08, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(9.728005e-08, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.52402425, shape=(), dtype=float32)
# Epoch 11: loss: 2.7407 real_loss: 0.1749
#
# Start of epoch 12
#
#  loss_u_inlet:tf.Tensor(0.48293042, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.076807596, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.838278e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.0953005e-08, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(8.4285084e-08, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.4857172, shape=(), dtype=float32)
# Epoch 12: loss: 2.6792 real_loss: 0.1593
#
# Start of epoch 13
#
#  loss_u_inlet:tf.Tensor(0.42970657, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.09099245, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.8539578e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(8.4764466e-08, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(8.4838845e-08, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.44239917, shape=(), dtype=float32)
# Epoch 13: loss: 2.6337 real_loss: 0.1452
#
# Start of epoch 14
#
#  loss_u_inlet:tf.Tensor(0.3812042, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.10624617, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.7031423e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.6665251e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.1109552e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.40263578, shape=(), dtype=float32)
# Epoch 14: loss: 2.6168 real_loss: 0.1349
#
# Start of epoch 15
#
#  loss_u_inlet:tf.Tensor(0.3453027, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.11835594, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.4518262e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.8295966e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.6993798e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3722892, shape=(), dtype=float32)
# Epoch 15: loss: 2.6191 real_loss: 0.1297
#
# Start of epoch 16
#
#  loss_u_inlet:tf.Tensor(0.32578796, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.123492144, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.2465058e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.0701877e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.4965584e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.35427445, shape=(), dtype=float32)
# Epoch 16: loss: 2.6197 real_loss: 0.1296
#
# Start of epoch 17
#
#  loss_u_inlet:tf.Tensor(0.32318512, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.11995301, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.230252e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(5.023971e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.1925026e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.34911466, shape=(), dtype=float32)
# Epoch 17: loss: 2.6033 real_loss: 0.1343
#
# Start of epoch 18
#
#  loss_u_inlet:tf.Tensor(0.33598393, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.10883478, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.4620904e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(5.4587457e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.4938898e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3556738, shape=(), dtype=float32)
# Epoch 18: loss: 2.5715 real_loss: 0.1429
#
# Start of epoch 19
#
#  loss_u_inlet:tf.Tensor(0.3611575, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.09332029, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.8788147e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(5.3860896e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.331564e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3713733, shape=(), dtype=float32)
# Epoch 19: loss: 2.5381 real_loss: 0.1539
#
# Start of epoch 20
#
#  loss_u_inlet:tf.Tensor(0.3937486, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07730676, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.3144257e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.999863e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.8629685e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3919151, shape=(), dtype=float32)
# Epoch 20: loss: 2.5169 real_loss: 0.1649
#
# Start of epoch 21
#
#  loss_u_inlet:tf.Tensor(0.42647207, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06406943, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.5824763e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.5522e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.3248163e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.41136637, shape=(), dtype=float32)
# Epoch 21: loss: 2.5109 real_loss: 0.1730
#
# Start of epoch 22
#
#  loss_u_inlet:tf.Tensor(0.450739, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.055402458, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.5883273e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.267027e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.8980266e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.42345718, shape=(), dtype=float32)
# Epoch 22: loss: 2.5106 real_loss: 0.1762
#
# Start of epoch 23
#
#  loss_u_inlet:tf.Tensor(0.45953152, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.0515972, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.384831e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.302624e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.6704189e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.42390153, shape=(), dtype=float32)
# Epoch 23: loss: 2.5028 real_loss: 0.1738
#
# Start of epoch 24
#
#  loss_u_inlet:tf.Tensor(0.4506221, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.052090913, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.122717e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.734959e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.6671542e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.4123874, shape=(), dtype=float32)
# Epoch 24: loss: 2.4824 real_loss: 0.1671
#
# Start of epoch 25
#
#  loss_u_inlet:tf.Tensor(0.42749825, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.056057584, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.9473107e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(5.5659416e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.8952694e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.39254767, shape=(), dtype=float32)
# Epoch 25: loss: 2.4565 real_loss: 0.1584
#
# Start of epoch 26
#
#  loss_u_inlet:tf.Tensor(0.3975811, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.062368587, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(2.9231423e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(6.734496e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.3582213e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.37001994, shape=(), dtype=float32)
# Epoch 26: loss: 2.4370 real_loss: 0.1505
#
# Start of epoch 27
#
#  loss_u_inlet:tf.Tensor(0.36930665, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.069235735, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.0178067e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(8.092966e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.020378e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3500623, shape=(), dtype=float32)
# Epoch 27: loss: 2.4292 real_loss: 0.1452
#
# Start of epoch 28
#
#  loss_u_inlet:tf.Tensor(0.34952196, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.074327976, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.1421958e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(9.3889184e-07, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.7597414e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3360169, shape=(), dtype=float32)
# Epoch 28: loss: 2.4273 real_loss: 0.1435
#
# Start of epoch 29
#
#  loss_u_inlet:tf.Tensor(0.3420722, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07567772, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.2221775e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.0340834e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(4.3885075e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.32914573, shape=(), dtype=float32)
# Epoch 29: loss: 2.4205 real_loss: 0.1459
#
# Start of epoch 30
#
#  loss_u_inlet:tf.Tensor(0.34766507, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07273832, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.2485957e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.0790338e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(4.7587938e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.32931557, shape=(), dtype=float32)
# Epoch 30: loss: 2.4045 real_loss: 0.1516
#
# Start of epoch 31
#
#  loss_u_inlet:tf.Tensor(0.36423707, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06666946, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.270282e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.0801801e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(4.865591e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3354595, shape=(), dtype=float32)
# Epoch 31: loss: 2.3842 real_loss: 0.1593
#
# Start of epoch 32
#
#  loss_u_inlet:tf.Tensor(0.3871098, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.059671216, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.3453656e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.0621605e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(4.850136e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3453412, shape=(), dtype=float32)
# Epoch 32: loss: 2.3690 real_loss: 0.1670
#
# Start of epoch 33
#
#  loss_u_inlet:tf.Tensor(0.40929118, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.053921964, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.4897766e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.05568e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(4.9234944e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.35522965, shape=(), dtype=float32)
# Epoch 33: loss: 2.3621 real_loss: 0.1722
#
# Start of epoch 34
#
#  loss_u_inlet:tf.Tensor(0.42319968, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.05078596, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.65905e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.0870247e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(5.288673e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.36067447, shape=(), dtype=float32)
# Epoch 34: loss: 2.3581 real_loss: 0.1733
#
# Start of epoch 35
#
#  loss_u_inlet:tf.Tensor(0.4239268, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.050700765, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.7817328e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.1736582e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(6.099355e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3586322, shape=(), dtype=float32)
# Epoch 35: loss: 2.3495 real_loss: 0.1702
#
# Start of epoch 36
#
#  loss_u_inlet:tf.Tensor(0.41185954, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.05346818, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.8178332e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.3218711e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(7.4225073e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.34934565, shape=(), dtype=float32)
# Epoch 36: loss: 2.3352 real_loss: 0.1647
#
# Start of epoch 37
#
#  loss_u_inlet:tf.Tensor(0.39231586, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.05832715, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.787541e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.5224416e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(9.168427e-07, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3361216, shape=(), dtype=float32)
# Epoch 37: loss: 2.3213 real_loss: 0.1592
#
# Start of epoch 38
#
#  loss_u_inlet:tf.Tensor(0.37278312, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06375734, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.750403e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.7467462e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.1022199e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.323359, shape=(), dtype=float32)
# Epoch 38: loss: 2.3123 real_loss: 0.1559
#
# Start of epoch 39
#
#  loss_u_inlet:tf.Tensor(0.35982826, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.067706086, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.7595953e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.9535717e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.2504686e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.31451073, shape=(), dtype=float32)
# Epoch 39: loss: 2.3062 real_loss: 0.1559
#
# Start of epoch 40
#
#  loss_u_inlet:tf.Tensor(0.35710457, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06859302, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.8293623e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.1109695e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.3235033e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.31112438, shape=(), dtype=float32)
# Epoch 40: loss: 2.2977 real_loss: 0.1594
#
# Start of epoch 41
#
#  loss_u_inlet:tf.Tensor(0.36470595, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06633793, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(3.9381284e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.2191587e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.3205827e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.31293634, shape=(), dtype=float32)
# Epoch 41: loss: 2.2856 real_loss: 0.1652
#
# Start of epoch 42
#
#  loss_u_inlet:tf.Tensor(0.3792116, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.062405564, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.0536605e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.3118462e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.2810161e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3181761, shape=(), dtype=float32)
# Epoch 42: loss: 2.2739 real_loss: 0.1713
#
# Start of epoch 43
#
#  loss_u_inlet:tf.Tensor(0.39424285, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.058834273, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.1529725e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.4313426e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.2631496e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.323746, shape=(), dtype=float32)
# Epoch 43: loss: 2.2657 real_loss: 0.1753
#
# Start of epoch 44
#
#  loss_u_inlet:tf.Tensor(0.4024706, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.057132546, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.2265685e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.602715e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.3215183e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.32602516, shape=(), dtype=float32)
# Epoch 44: loss: 2.2585 real_loss: 0.1757
#
# Start of epoch 45
#
#  loss_u_inlet:tf.Tensor(0.39932415, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.057846922, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.275071e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.8350667e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.4938192e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.32277045, shape=(), dtype=float32)
# Epoch 45: loss: 2.2483 real_loss: 0.1726
#
# Start of epoch 46
#
#  loss_u_inlet:tf.Tensor(0.3858813, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06070438, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.3068652e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(3.1345726e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.790943e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.31471768, shape=(), dtype=float32)
# Epoch 46: loss: 2.2355 real_loss: 0.1682
#
# Start of epoch 47
#
#  loss_u_inlet:tf.Tensor(0.36821398, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06466905, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.3368484e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(3.4907268e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.1797325e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3051389, shape=(), dtype=float32)
# Epoch 47: loss: 2.2246 real_loss: 0.1649
#
# Start of epoch 48
#
#  loss_u_inlet:tf.Tensor(0.3538909, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.0679851, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.3827353e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(3.8531957e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.5715863e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.2978228, shape=(), dtype=float32)
# Epoch 48: loss: 2.2161 real_loss: 0.1646
#
# Start of epoch 49
#
#  loss_u_inlet:tf.Tensor(0.34822896, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.068950005, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.4585817e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.1540784e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.8553507e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.295227, shape=(), dtype=float32)
# Epoch 49: loss: 2.2065 real_loss: 0.1676
#
# Start of epoch 50
#
#  loss_u_inlet:tf.Tensor(0.35219654, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.0671505, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.5683722e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.3695636e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.973746e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29774958, shape=(), dtype=float32)
# Epoch 50: loss: 2.1940 real_loss: 0.1729
#
# Start of epoch 51
#
#  loss_u_inlet:tf.Tensor(0.36211297, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06382536, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.703211e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.551154e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.970953e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30367097, shape=(), dtype=float32)
# Epoch 51: loss: 2.1814 real_loss: 0.1779
#
# Start of epoch 52
#
#  loss_u_inlet:tf.Tensor(0.37091172, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06091128, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.8453767e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.784671e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.9608805e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30946344, shape=(), dtype=float32)
# Epoch 52: loss: 2.1708 real_loss: 0.1802
#
# Start of epoch 53
#
#  loss_u_inlet:tf.Tensor(0.37163463, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.059806153, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(4.97983e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(5.121e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.0551676e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.31133962, shape=(), dtype=float32)
# Epoch 53: loss: 2.1595 real_loss: 0.1790
#
# Start of epoch 54
#
#  loss_u_inlet:tf.Tensor(0.36213472, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.060831543, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(5.1049974e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(5.554174e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.3079282e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30792537, shape=(), dtype=float32)
# Epoch 54: loss: 2.1458 real_loss: 0.1758
#
# Start of epoch 55
#
#  loss_u_inlet:tf.Tensor(0.34680152, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06320165, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(5.2321837e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(6.0488237e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.6909682e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3014331, shape=(), dtype=float32)
# Epoch 55: loss: 2.1322 real_loss: 0.1734
#
# Start of epoch 56
#
#  loss_u_inlet:tf.Tensor(0.33339754, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.065177575, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(5.3759148e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(6.5574427e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(4.096438e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29591933, shape=(), dtype=float32)
# Epoch 56: loss: 2.1200 real_loss: 0.1740
#
# Start of epoch 57
#
#  loss_u_inlet:tf.Tensor(0.32783508, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06505217, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(5.5463814e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(7.03894e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(4.394808e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29449055, shape=(), dtype=float32)
# Epoch 57: loss: 2.1064 real_loss: 0.1779
#
# Start of epoch 58
#
#  loss_u_inlet:tf.Tensor(0.33059096, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06269071, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(5.7452962e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(7.501212e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(4.5420443e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29758668, shape=(), dtype=float32)
# Epoch 58: loss: 2.0909 real_loss: 0.1832
#
# Start of epoch 59
#
#  loss_u_inlet:tf.Tensor(0.33630207, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.05972197, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(5.9584196e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(7.999785e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(4.629372e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30261743, shape=(), dtype=float32)
# Epoch 59: loss: 2.0762 real_loss: 0.1869
#
# Start of epoch 60
#
#  loss_u_inlet:tf.Tensor(0.33688313, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.05801975, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.1530496e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(8.569225e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(4.812616e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3051777, shape=(), dtype=float32)
# Epoch 60: loss: 2.0619 real_loss: 0.1869
#
# Start of epoch 61
#
#  loss_u_inlet:tf.Tensor(0.327901, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.058305338, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.299587e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(9.197595e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(5.1854317e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30259508, shape=(), dtype=float32)
# Epoch 61: loss: 2.0457 real_loss: 0.1846
#
# Start of epoch 62
#
#  loss_u_inlet:tf.Tensor(0.3129246, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.0598525, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.40008e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(9.875486e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(5.6880754e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29684442, shape=(), dtype=float32)
# Epoch 62: loss: 2.0291 real_loss: 0.1834
#
# Start of epoch 63
#
#  loss_u_inlet:tf.Tensor(0.3004538, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.060835764, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.485679e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.06193e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(6.1137152e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.2928844, shape=(), dtype=float32)
# Epoch 63: loss: 2.0132 real_loss: 0.1858
#
# Start of epoch 64
#
#  loss_u_inlet:tf.Tensor(0.29635584, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.059770294, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.584695e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.1486222e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(6.273913e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.294212, shape=(), dtype=float32)
# Epoch 64: loss: 1.9958 real_loss: 0.1912
#
# Start of epoch 65
#
#  loss_u_inlet:tf.Tensor(0.29875672, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.057264447, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.694152e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.2575934e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(6.2125914e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29988876, shape=(), dtype=float32)
# Epoch 65: loss: 1.9777 real_loss: 0.1962
#
# Start of epoch 66
#
#  loss_u_inlet:tf.Tensor(0.29922712, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.055369828, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.782008e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.38884525e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(6.1857104e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30478492, shape=(), dtype=float32)
# Epoch 66: loss: 1.9602 real_loss: 0.1974
#
# Start of epoch 67
#
#  loss_u_inlet:tf.Tensor(0.29073867, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.055353507, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.823899e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.526055e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(6.4093138e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30413076, shape=(), dtype=float32)
# Epoch 67: loss: 1.9415 real_loss: 0.1960
#
# Start of epoch 68
#
#  loss_u_inlet:tf.Tensor(0.27599502, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.056688562, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.838955e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.6637066e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(6.8466247e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.2993185, shape=(), dtype=float32)
# Epoch 68: loss: 1.9223 real_loss: 0.1962
#
# Start of epoch 69
#
#  loss_u_inlet:tf.Tensor(0.26462585, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.05748626, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.8774476e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.8245055e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(7.222829e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29652214, shape=(), dtype=float32)
# Epoch 69: loss: 1.9034 real_loss: 0.2008
#
# Start of epoch 70
#
#  loss_u_inlet:tf.Tensor(0.26184383, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.056626186, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.9703296e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.0379039e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(7.3339993e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29935318, shape=(), dtype=float32)
# Epoch 70: loss: 1.8831 real_loss: 0.2072
#
# Start of epoch 71
#
#  loss_u_inlet:tf.Tensor(0.2620501, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.055501707, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.095049e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.3027287e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(7.348587e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3043735, shape=(), dtype=float32)
# Epoch 71: loss: 1.8631 real_loss: 0.2104
#
# Start of epoch 72
#
#  loss_u_inlet:tf.Tensor(0.2551549, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.055913046, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.20043e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.5734422e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(7.606853e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30457842, shape=(), dtype=float32)
# Epoch 72: loss: 1.8428 real_loss: 0.2099
#
# Start of epoch 73
#
#  loss_u_inlet:tf.Tensor(0.24087417, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.05773779, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.2779316e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.8324259e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(8.1412445e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29951072, shape=(), dtype=float32)
# Epoch 73: loss: 1.8218 real_loss: 0.2111
#
# Start of epoch 74
#
#  loss_u_inlet:tf.Tensor(0.22985114, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.059148207, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.3761184e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(3.1467487e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(8.55815e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29683352, shape=(), dtype=float32)
# Epoch 74: loss: 1.8013 real_loss: 0.2171
#
# Start of epoch 75
#
#  loss_u_inlet:tf.Tensor(0.2274822, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.05918155, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.522275e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(3.5828107e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(8.59016e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30078745, shape=(), dtype=float32)
# Epoch 75: loss: 1.7800 real_loss: 0.2235
#
# Start of epoch 76
#
#  loss_u_inlet:tf.Tensor(0.22513738, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.05949542, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.671382e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.0845018e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(8.591624e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30510134, shape=(), dtype=float32)
# Epoch 76: loss: 1.7593 real_loss: 0.2247
#
# Start of epoch 77
#
#  loss_u_inlet:tf.Tensor(0.21400742, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06129416, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.7816534e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.5333996e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(8.966034e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3025662, shape=(), dtype=float32)
# Epoch 77: loss: 1.7381 real_loss: 0.2251
#
# Start of epoch 78
#
#  loss_u_inlet:tf.Tensor(0.2017348, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06349385, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.9034304e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.9913102e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(9.425212e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29886705, shape=(), dtype=float32)
# Epoch 78: loss: 1.7176 real_loss: 0.2310
#
# Start of epoch 79
#
#  loss_u_inlet:tf.Tensor(0.19821435, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06457007, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(8.103377e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(5.6148707e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(9.474852e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30214655, shape=(), dtype=float32)
# Epoch 79: loss: 1.6969 real_loss: 0.2378
#
# Start of epoch 80
#
#  loss_u_inlet:tf.Tensor(0.19579309, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06584225, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(8.349688e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(6.304158e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(9.484577e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30622703, shape=(), dtype=float32)
# Epoch 80: loss: 1.6771 real_loss: 0.2386
#
# Start of epoch 81
#
#  loss_u_inlet:tf.Tensor(0.18468408, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.06855623, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(8.5929256e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(6.8445246e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(9.984153e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30232412, shape=(), dtype=float32)
# Epoch 81: loss: 1.6572 real_loss: 0.2404
#
# Start of epoch 82
#
#  loss_u_inlet:tf.Tensor(0.17542966, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07129554, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(8.8934845e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(7.423975e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.04326455e-05, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29952964, shape=(), dtype=float32)
# Epoch 82: loss: 1.6384 real_loss: 0.2482
#
# Start of epoch 83
#
#  loss_u_inlet:tf.Tensor(0.17448367, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.073070385, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(9.285607e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(8.222218e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.0384426e-05, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30406982, shape=(), dtype=float32)
# Epoch 83: loss: 1.6200 real_loss: 0.2516
#
# Start of epoch 84
#
#  loss_u_inlet:tf.Tensor(0.1680684, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07572928, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(9.667027e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(8.8868124e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.065684e-05, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30324554, shape=(), dtype=float32)
# Epoch 84: loss: 1.6023 real_loss: 0.2516
#
# Start of epoch 85
#
#  loss_u_inlet:tf.Tensor(0.15817454, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.078968145, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.00010027109, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(9.4264906e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.1153289e-05, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29863304, shape=(), dtype=float32)
# Epoch 85: loss: 1.5857 real_loss: 0.2590
#
# Start of epoch 86
#
#  loss_u_inlet:tf.Tensor(0.15766168, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.08088021, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.0001043642, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00010249527, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.0957052e-05, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30299056, shape=(), dtype=float32)
# Epoch 86: loss: 1.5696 real_loss: 0.2624
#
# Start of epoch 87
#
#  loss_u_inlet:tf.Tensor(0.15302148, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.083400816, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.00010786225, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.000109121516, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.1007366e-05, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30283022, shape=(), dtype=float32)
# Epoch 87: loss: 1.5545 real_loss: 0.2622
#
# Start of epoch 88
#
#  loss_u_inlet:tf.Tensor(0.14529023, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.08648444, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.00011074348, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00011409053, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.1261414e-05, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29883608, shape=(), dtype=float32)
# Epoch 88: loss: 1.5404 real_loss: 0.2703
#
# Start of epoch 89
#
#  loss_u_inlet:tf.Tensor(0.1469042, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.087977365, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.000113915594, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00012234492, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.07499645e-05, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30414122, shape=(), dtype=float32)
# Epoch 89: loss: 1.5269 real_loss: 0.2696
#
# Start of epoch 90
#
#  loss_u_inlet:tf.Tensor(0.13992535, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.0909685, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.000115922754, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00012632617, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.0869299e-05, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29957846, shape=(), dtype=float32)
# Epoch 90: loss: 1.5140 real_loss: 0.2738
#
# Start of epoch 91
#
#  loss_u_inlet:tf.Tensor(0.13848302, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.0928177, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.00011776597, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00013187536, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.0500653e-05, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30048516, shape=(), dtype=float32)
# Epoch 91: loss: 1.5019 real_loss: 0.2777
#
# Start of epoch 92
#
#  loss_u_inlet:tf.Tensor(0.13745783, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.094355166, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.0001189068, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00013658557, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(1.0045284e-05, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3014871, shape=(), dtype=float32)
# Epoch 92: loss: 1.4906 real_loss: 0.2761
#
# Start of epoch 93
#
#  loss_u_inlet:tf.Tensor(0.13188723, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.09677629, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.000118844844, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00013775966, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(9.900273e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.2971422, shape=(), dtype=float32)
# Epoch 93: loss: 1.4799 real_loss: 0.2848
#
# Start of epoch 94
#
#  loss_u_inlet:tf.Tensor(0.136387, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.0962883, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.000118822005, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00014252213, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(8.9201985e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.303968, shape=(), dtype=float32)
# Epoch 94: loss: 1.4701 real_loss: 0.2760
#
# Start of epoch 95
#
#  loss_u_inlet:tf.Tensor(0.12561408, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.100006, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.00011682745, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00013796799, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(9.088905e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29331735, shape=(), dtype=float32)
# Epoch 95: loss: 1.4614 real_loss: 0.2945
#
# Start of epoch 96
#
#  loss_u_inlet:tf.Tensor(0.13989165, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.09581003, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.00011641752, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00014464019, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(7.41154e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.31100187, shape=(), dtype=float32)
# Epoch 96: loss: 1.4550 real_loss: 0.2688
#
# Start of epoch 97
#
#  loss_u_inlet:tf.Tensor(0.11537314, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.10487573, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.00011232721, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00012972397, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(8.544073e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.28401947, shape=(), dtype=float32)
# Epoch 97: loss: 1.4528 real_loss: 0.3084
#
# Start of epoch 98
#
#  loss_u_inlet:tf.Tensor(0.14931665, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.09296191, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.00011284329, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00014303127, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(5.7493794e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3238527, shape=(), dtype=float32)
# Epoch 98: loss: 1.4529 real_loss: 0.2673
#
# Start of epoch 99
#
#  loss_u_inlet:tf.Tensor(0.1111226, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.10645198, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.00010693782, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00011922445, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(7.545267e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.28101698, shape=(), dtype=float32)
# Epoch 99: loss: 1.4419 real_loss: 0.2931
#
# Start of epoch 100
#
#  loss_u_inlet:tf.Tensor(0.13153814, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.09606702, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.00010590726, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00012353488, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(5.6120025e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.305812, shape=(), dtype=float32)
# Epoch 100: loss: 1.4219 real_loss: 0.2965
#
# Start of epoch 101
#
#  loss_u_inlet:tf.Tensor(0.13351518, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.09425995, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(0.00010305417, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(0.00011711405, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(5.0504073e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3092226, shape=(), dtype=float32)
# Epoch 101: loss: 1.4171 real_loss: 0.2694
#
# Start of epoch 102
#
#  loss_u_inlet:tf.Tensor(0.10926844, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.104156494, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(9.803577e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(9.876104e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(5.958134e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.28201845, shape=(), dtype=float32)
# Epoch 102: loss: 1.4194 real_loss: 0.2996
#
# Start of epoch 103
#
#  loss_u_inlet:tf.Tensor(0.13442437, shape=(), dtype=float32)
# ...
#  Euler_y_residual:tf.Tensor(3.5171774e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3133982, shape=(), dtype=float32)
# Epoch 106: loss: 1.3892 real_loss: 0.2842
#
# Start of epoch 107
#
#  loss_u_inlet:tf.Tensor(0.1160295, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.09145619, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(8.800402e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(6.31942e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.8720295e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29571506, shape=(), dtype=float32)
# Epoch 107: loss: 1.3767 real_loss: 0.2772
#
# Start of epoch 108
#
#  loss_u_inlet:tf.Tensor(0.1088292, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.09310705, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(8.593206e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(5.4853983e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.959566e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.28783864, shape=(), dtype=float32)
# Epoch 108: loss: 1.3743 real_loss: 0.2992
#
# Start of epoch 109
#
#  loss_u_inlet:tf.Tensor(0.12774673, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.08316943, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(8.586157e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(5.3159834e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.1093775e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3109458, shape=(), dtype=float32)
# Epoch 109: loss: 1.3712 real_loss: 0.2823
#
# Start of epoch 110
#
#  loss_u_inlet:tf.Tensor(0.11071023, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.088194534, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(8.3379884e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(4.4439726e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.5196706e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29139805, shape=(), dtype=float32)
# Epoch 110: loss: 1.3606 real_loss: 0.2812
#
# Start of epoch 111
#
#  loss_u_inlet:tf.Tensor(0.10842997, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.087410584, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(8.20573e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(3.956848e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.4555417e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.28908575, shape=(), dtype=float32)
# Epoch 111: loss: 1.3560 real_loss: 0.2987
#
# Start of epoch 112
#
#  loss_u_inlet:tf.Tensor(0.12346847, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07961975, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(8.209421e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(3.8083337e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.8598718e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.30698738, shape=(), dtype=float32)
# Epoch 112: loss: 1.3540 real_loss: 0.2819
#
# Start of epoch 113
#
#  loss_u_inlet:tf.Tensor(0.10640371, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.08482473, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(8.019623e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(3.217606e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.2674725e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.28709623, shape=(), dtype=float32)
# Epoch 113: loss: 1.3458 real_loss: 0.2859
#
# Start of epoch 114
#
#  loss_u_inlet:tf.Tensor(0.10854673, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.082248464, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.966169e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.9691533e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.0850583e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.28965455, shape=(), dtype=float32)
# Epoch 114: loss: 1.3396 real_loss: 0.2986
#
# Start of epoch 115
#
#  loss_u_inlet:tf.Tensor(0.11916937, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.076815516, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.968129e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.8533961e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.6945418e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.3018005, shape=(), dtype=float32)
# Epoch 115: loss: 1.3377 real_loss: 0.2827
#
# Start of epoch 116
#
#  loss_u_inlet:tf.Tensor(0.102998614, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.08198168, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.802869e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.4579256e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.076541e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.28290358, shape=(), dtype=float32)
# Epoch 116: loss: 1.3319 real_loss: 0.2914
#
# Start of epoch 117
#
#  loss_u_inlet:tf.Tensor(0.109560266, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07804476, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.774684e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.3488941e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.8034956e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.2902721, shape=(), dtype=float32)
# Epoch 117: loss: 1.3249 real_loss: 0.2981
#
# Start of epoch 118
#
#  loss_u_inlet:tf.Tensor(0.11459192, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07531239, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.7350385e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(2.2347313e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.6146413e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.29559132, shape=(), dtype=float32)
# Epoch 118: loss: 1.3218 real_loss: 0.2848
#
# Start of epoch 119
#
#  loss_u_inlet:tf.Tensor(0.10092272, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.08003277, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.591403e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.9660554e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.9414105e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.27952698, shape=(), dtype=float32)
# Epoch 119: loss: 1.3180 real_loss: 0.2973
#
# Start of epoch 120
#
#  loss_u_inlet:tf.Tensor(0.111232206, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.075280026, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.596527e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.9272666e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.6141115e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.2906896, shape=(), dtype=float32)
# Epoch 120: loss: 1.3114 real_loss: 0.2966
#
# Start of epoch 121
#
#  loss_u_inlet:tf.Tensor(0.109377414, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07560205, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.541692e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.7935206e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.6321668e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.2879127, shape=(), dtype=float32)
# Epoch 121: loss: 1.3064 real_loss: 0.2886
#
# Start of epoch 122
#
#  loss_u_inlet:tf.Tensor(0.10081357, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07888668, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.454467e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.6214935e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.8433933e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.27749062, shape=(), dtype=float32)
# Epoch 122: loss: 1.3032 real_loss: 0.3022
#
# Start of epoch 123
#
#  loss_u_inlet:tf.Tensor(0.11237435, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07429142, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.4797e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.6057098e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.5337174e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.28960785, shape=(), dtype=float32)
# Epoch 123: loss: 1.2984 real_loss: 0.2945
#
# Start of epoch 124
#
#  loss_u_inlet:tf.Tensor(0.10398887, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07753944, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.393853e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.4579417e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.7408496e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.27937445, shape=(), dtype=float32)
# Epoch 124: loss: 1.2925 real_loss: 0.2949
#
# Start of epoch 125
#
#  loss_u_inlet:tf.Tensor(0.10336603, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07798451, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.342487e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.3723663e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.7644523e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.27770165, shape=(), dtype=float32)
# Epoch 125: loss: 1.2881 real_loss: 0.3040
#
# Start of epoch 126
#
#  loss_u_inlet:tf.Tensor(0.11092694, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07529928, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.328563e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.34365455e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.5914871e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.28502113, shape=(), dtype=float32)
# Epoch 126: loss: 1.2847 real_loss: 0.2935
#
# Start of epoch 127
#
#  loss_u_inlet:tf.Tensor(0.10035227, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.079879224, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.215634e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.2156236e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.8828492e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.2721132, shape=(), dtype=float32)
# Epoch 127: loss: 1.2803 real_loss: 0.3025
#
# Start of epoch 128
#
#  loss_u_inlet:tf.Tensor(0.10765156, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.0771235, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.195744e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.1973337e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.716692e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.27905977, shape=(), dtype=float32)
# Epoch 128: loss: 1.2751 real_loss: 0.3015
#
# Start of epoch 129
#
#  loss_u_inlet:tf.Tensor(0.105768666, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07817203, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.12956e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.1340249e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.7944193e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.2757417, shape=(), dtype=float32)
# Epoch 129: loss: 1.2707 real_loss: 0.2972
#
# Start of epoch 130
#
#  loss_u_inlet:tf.Tensor(0.10111641, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.080442645, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.053213e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.062616e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.952803e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.2693031, shape=(), dtype=float32)
# Epoch 130: loss: 1.2673 real_loss: 0.3070
#
# Start of epoch 131
#
#  loss_u_inlet:tf.Tensor(0.109292835, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.0772784, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.052531e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(1.0590341e-05, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.7801213e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.27715945, shape=(), dtype=float32)
# Epoch 131: loss: 1.2637 real_loss: 0.2979
#
# Start of epoch 132
#
#  loss_u_inlet:tf.Tensor(0.10036823, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.08117604, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.977539e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(9.748896e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.0501342e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.26598415, shape=(), dtype=float32)
# Epoch 132: loss: 1.2594 real_loss: 0.3053
#
# Start of epoch 133
#
#  loss_u_inlet:tf.Tensor(0.106232226, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.078731455, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.996907e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(9.619467e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(2.9323091e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.27130347, shape=(), dtype=float32)
# Epoch 133: loss: 1.2549 real_loss: 0.3037
#
# Start of epoch 134
#
#  loss_u_inlet:tf.Tensor(0.10411736, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07962921, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(6.9958776e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(9.125755e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.025728e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.26768577, shape=(), dtype=float32)
# Epoch 134: loss: 1.2508 real_loss: 0.3014
#
# Start of epoch 135
#
#  loss_u_inlet:tf.Tensor(0.101540715, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.08070205, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.012892e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(8.617075e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.1336442e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.26351428, shape=(), dtype=float32)
# Epoch 135: loss: 1.2471 real_loss: 0.3083
#
# Start of epoch 136
#
#  loss_u_inlet:tf.Tensor(0.10724902, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07822512, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.091016e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(8.437851e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.0230685e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.26860443, shape=(), dtype=float32)
# Epoch 136: loss: 1.2436 real_loss: 0.2999
#
# Start of epoch 137
#
#  loss_u_inlet:tf.Tensor(0.09942415, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.08140932, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.114386e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(7.720969e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.2678788e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.25855, shape=(), dtype=float32)
# Epoch 137: loss: 1.2400 real_loss: 0.3093
#
# Start of epoch 138
#
#  loss_u_inlet:tf.Tensor(0.107468024, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.077859655, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.229076e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(7.5903868e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.092456e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.26627612, shape=(), dtype=float32)
# Epoch 138: loss: 1.2360 real_loss: 0.3010
#
# Start of epoch 139
#
#  loss_u_inlet:tf.Tensor(0.09994778, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.080812514, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.269668e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(6.9135554e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.32476e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.25656217, shape=(), dtype=float32)
# Epoch 139: loss: 1.2318 real_loss: 0.3077
#
# Start of epoch 140
#
#  loss_u_inlet:tf.Tensor(0.105804026, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07818631, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.379495e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(6.68478e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.2076764e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.26178342, shape=(), dtype=float32)
# Epoch 140: loss: 1.2276 real_loss: 0.3029
#
# Start of epoch 141
#
#  loss_u_inlet:tf.Tensor(0.10165082, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07975149, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.435143e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(6.1621963e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.3518882e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.2557564, shape=(), dtype=float32)
# Epoch 141: loss: 1.2234 real_loss: 0.3052
#
# Start of epoch 142
#
#  loss_u_inlet:tf.Tensor(0.10393369, shape=(), dtype=float32)
#  loss_u_wall:tf.Tensor(0.07870624, shape=(), dtype=float32)
#  loss_p_outlet:tf.Tensor(7.517291e-05, shape=(), dtype=float32)
#  Euler_x_residual:tf.Tensor(5.8437868e-06, shape=(), dtype=float32)
#  Euler_y_residual:tf.Tensor(3.332182e-06, shape=(), dtype=float32)
#  loss_IC:tf.Tensor(0.2568599, shape=(), dtype=float32)

# %% [markdown]
# test which code is the fastest

# %%
import time

ux, uy, p = net_uv(x_data[0,...])

ux = ux[:,indice:,0]
uy = uy[:,indice:,0]
p =  p[:,indice:,0]


start_time = time.time()

for i in range(50):

  ux_inlet_BC = y_data[:,indice:,0][mask_inlet != 0]

  ux_inlet_pred = ux[mask_inlet != 0]
  uy_inlet_pred = uy[mask_inlet != 0]

  loss_u_inlet = tf.reduce_mean(tf.square(ux_inlet_BC - ux_inlet_pred)) + tf.reduce_mean(tf.square(uy_inlet_pred))


print("--- %s seconds ---" % (time.time() - start_time))


start_time = time.time()

for i in range(50):

  ux_inlet_BC = y_data[:,indice:,0]*mask_inlet

  ux_inlet_pred = ux*mask_inlet
  uy_inlet_pred = uy*mask_inlet

  loss_u_inlet = tf.reduce_sum(tf.square(ux_inlet_BC - ux_inlet_pred))/n_inlet + tf.reduce_sum(tf.square(uy_inlet_pred))/n_inlet


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.21057748794555664 seconds ---
# --- 0.1858210563659668 seconds ---

# %%
print(mask_inlet.shape)
print(x_data.shape)
x_data[0,0:1,indice:,0][mask_inlet == 0]
# Out:
# (1, 258400)
# (1, 1, 271320, 3)
# array([0.0101389 , 0.0101389 , 0.0304167 , ..., 4.95015001, 4.97008991,
#        4.99002981])

# %%
model_ref.compile(optimizer,loss_object)
#loss_object = tf.keras.losses.MeanSquaredError()

# score = model_ref.evaluate(x_data[0,...],y_data, verbose=1)

# print('Average Mean Squared Error:', score)
model_ref.save('my_model_ref.h5')

# %%
from google.colab import files
files.download('my_model_ref.h5')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

time = 0

fig = plt.figure(figsize= (20,5))
# plt.scatter(x = x_data[0,0,:indice,3], y = x_data[0,0,:indice,4], c = y_prev[0,(time)*indice:(time+1)*indice,0], cmap='jet', vmax=1.5 ,vmin=-1.0 )
# plt.colorbar()

plt.ylabel('prediction_ref')
plt.scatter(x = x_data[0,0,:indice,0], y = x_data[0,0,:indice,1], c = mask_obstacle[0,:indice] )

# %%
pip install idaes-pse

# %%
import numpy as np
import idaes.surrogate.pysmo.sampling as rbf
data = rbf.LatinHypercubeSampling(x_test[0,:,:indice,:], 1000, sampling_type="selection")
data = data.sample_points()

# %%
import random 
idx_f_model = random.sample(range(0, indice) , 700 )#x_data.shape[2]), 10000)

x = np.take(x_data[0,0:1,:indice,0:1], idx_f_model, axis=1)
y = np.take(x_data[0,0:1,:indice,1:2], idx_f_model, axis=1)
t = np.take(x_data[0,0:1,:indice,2:3], idx_f_model, axis=1)

plt.scatter(x[0,:,0],y[0,:,0])

# %%
fig = plt.figure(figsize=(40,20))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x[...],y[...],t[...])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

time = 5

fig = plt.figure(figsize= (20,15))
# plt.scatter(x = x_data[0,0,:indice,3], y = x_data[0,0,:indice,4], c = y_prev[0,(time)*indice:(time+1)*indice,0], cmap='jet', vmax=1.5 ,vmin=-1.0 )
# plt.colorbar()

ux, uy, uz = net_uv(x_data[0,...])

plt.subplot(311)
plt.ylabel('prediction_ref')
plt.scatter(x = x_data[0,0,:indice,0], y = x_data[0,0,:indice,1], c = ux[0,(time)*indice:(time+1)*indice,0], cmap='jet', vmax=1.5 ,vmin=-1 )
plt.colorbar()

plt.subplot(312)
plt.ylabel('prediction_ref')
plt.scatter(x = x_data[0,0,:indice,0], y = x_data[0,0,:indice,1], c = model_ref(x_data[0,...])[0,(time)*indice:(time+1)*indice,0], cmap='jet', vmax=3 ,vmin=-0 )
plt.colorbar()

plt.subplot(313)
plt.ylabel('CFD')
plt.scatter(x = x_data[0,0,:indice,0], y = x_data[0,0,:indice,1], c =  y_data[:,:,0:3][0,(time)*indice:(time+1)*indice,0], cmap='jet', vmax=1.5 ,vmin=-1.0 )
plt.colorbar()
